# %% [markdown]
# Name: Vedant Joshi
# PRN: 2020BTEIT00045
# Assignement: CA2

# %%
import cv2
# import lbg
# import compression
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

file=input("Enter your file name: ")

img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
img = cv2.resize(img, (128, 128))
print(img.shape)
plt.imshow(img, cmap='gray')
cv2.imwrite('compressed1.png',img)
# Out:
# (128, 128)
# True
